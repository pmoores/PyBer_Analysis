# %%
# 5.1.3 Display plots inline within the Jupyter Notebook directly below the code cell that produced it
# %matplotlib inline

# %%
# Import matplotlib dependency as "plt"
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot using the MATLAB method
# plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt() method - object-oriented programming
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create an empty plot with ax.plt()
# fig = plt.figure()
# ax = fig.add_subplot()

# %%
# Create the plot
# plt.plot(x_axis, y_axis)
# plt.show() can only be used once per session

# %%
# Create the plot and add a label for the legend using MATLAB method
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limit between 0 and 45.
plt.ylim(0, 45)

# Create a title.
plt.title("PyBer Fare by Month")

# Add a grid
plt.grid()

# Add the legend.
plt.legend()

# %%
# SKILL DRILL - 5.1.4 - Using the ax_plot method (OOP) create a plot and add formatting as per instructions
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis, marker="^", color="green", linewidth=2, label='Boston')

ax.set_xlabel('Date')
ax.set_ylabel('Fare($)')

ax.set_title("PyBer Fare by Month")

ax.legend("Boston")

ax.grid()

# %%
# 5.1.5 - Add ride-sharing data to use with bar chart
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot using the MATLAB method
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Add formatting

# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Create a title.
plt.title("PyBer Fare by Month")

# Add the legend.
plt.legend()

# %%
# Create a horizontal bar chart using MATLAB method
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Run the data on opposite axes
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# SKILL DRILL Invert the y-axis to have the months in ascending order
# Create the plot.
plt.barh(x_axis, y_axis, color="magenta", label="Boston")
plt.gca().invert_yaxis()

# Create labels for x and y axes
plt.ylabel("Date")
plt.xlabel("Fare($)")

# Create a title.
plt.title("PyBer Fare by Month")

# Add the legend.
plt.legend()

# %%
# 5.1.6 - Add data to use with bar chart
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create a bar chart using object-oriented method
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create a horizontal bar chart using the object-oriented method - ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Switch x and y axes
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="Cyan", label="Chicago")

# Invert y axis so that Jan is on top
plt.gca().invert_yaxis()

# Add a title
ax.set_title("PyBer Fare by Month")

# Add axis labels
ax.set_ylabel('Date')
ax.set_xlabel('Fare($)')

ax.legend("Chicago")

# %%
# Add data to use with scatter plots

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create scatter plot using plt.plot()
plt.plot(x_axis, y_axis, 'o')

# %%
# SKILL DRILL 5.1.7 - Create a scatter plot using the plt-scatter() method and switch axes so that Fare($) is on x-axis
plt.scatter(y_axis, x_axis, color='red', label='Chicago')

# Invert y axis so that Jan is on top
plt.gca().invert_yaxis()

# Add a title
plt.title("PyBer Fare by Month")

# Add axes labels
plt.ylabel("Date")
plt.xlabel("Fare($)")
              
# Add a limit for x axis data
plt.xlim([0, 50])

# Add a legend
plt.legend()

# %%
# Create a bubble chart using the MATLAB method
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
# Adjust the size of the markers by multiplying the data by any value (in this case 3)
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)
    
# Use the new y axis for the s parameter
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
# Adjust the size of the markers using Python's list comprehension technique
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
# Create a scatter plot using the object-oriented approach
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# SKILL DRILL 5.1.7 Create a bubble chart using object-oriented programming
fig, ax = plt.subplots()

ax.scatter(y_axis, x_axis, s = [i * 5 for i in y_axis], c="Skyblue", alpha=0.2, label="Boston", linewidth=2, edgecolors='black')

# Add a title
ax.set_title("PyBer Fare by Month")

# Add axis labels
ax.set_ylabel('Date')
ax.set_xlabel('Fare($)')

ax.legend("Boston")

# Invert y axis so that Jan is on top
plt.gca().invert_yaxis()

# Add a limit of 0 to 50 for x-axis data
ax.set_xlim([0, 50])
# Out:
# (0.0, 50.0)

# %%
# 5.1.8 Create a pie chart using the MATLAB method

plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
# Add formatting to pie chart
plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct ='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbac893d6d0>,
# ...
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.32930826971286276, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452757, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.23338752507546193, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.460981299980763, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065241, 0.5724820419136908, '11.7%'),
# ...

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
# Create a pie chart using the object-oriented interface and set size to 8 x 8
fig, ax = plt.subplots(figsize=(8, 8))

# Explode the two highest percentage months
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

# Assign twelve colours - one for each month
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]

# Formatting - labels on x-axis, explode, add shadow, label clockwise, add percentage to one decimal place for each wedge
ax.pie(y_axis, labels=x_axis, explode=explode_values, shadow=True, counterclock=False, startangle=90, autopct ='%.1f%%')

plt.show()
